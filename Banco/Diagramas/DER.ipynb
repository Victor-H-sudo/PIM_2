-- %% [markdown]
-- # [dbo].[Ecopontos]

-- %%
USE [PIM_2]
GO

-- %%
/****** Objeto:  Table [dbo].[Ecopontos]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ecopontos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](100) NOT NULL,
	[Endereco] [nvarchar](255) NULL,
	[TipoMaterialId] [int] NULL,
	[Email] [nvarchar](100) NULL,
	[Senha] [nvarchar](255) NULL,
	[LinkMaps] [nvarchar](500) NULL,
	[CNPJ] [char](14) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reciclagens]

-- %%
/****** Objeto:  Table [dbo].[Reciclagens]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reciclagens](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[LocalId] [int] NOT NULL,
	[TipoMaterialId] [int] NOT NULL,
	[Peso] [decimal](10, 2) NULL,
	[PontosGerados] [int] NULL,
	[Data] [datetime] NULL,
	[FotoMaterial] [nvarchar](255) NULL,
	[FotoPeso] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Recompensas]

-- %%
/****** Objeto:  Table [dbo].[Recompensas]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Recompensas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](100) NOT NULL,
	[Descricao] [nvarchar](255) NULL,
	[PontosNecessarios] [int] NOT NULL,
	[Validade] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Resgates]

-- %%
/****** Objeto:  Table [dbo].[Resgates]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Resgates](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UsuarioId] [int] NOT NULL,
	[RecompensaId] [int] NOT NULL,
	[Data] [datetime] NULL,
	[Status] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TiposMaterial]

-- %%
/****** Objeto:  Table [dbo].[TiposMaterial]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TiposMaterial](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](50) NOT NULL,
	[Multiplicador] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Objeto:  Table [dbo].[Usuarios]    Data do Script: 11/05/2026 15:23:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nome] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[Senha] [nvarchar](255) NOT NULL,
	[Pontos] [int] NULL,
	[DataCadastro] [datetime] NULL,
	[CPF] [char](11) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Reciclagen__Data__5441852A]

-- %%
ALTER TABLE [dbo].[Reciclagens] ADD  DEFAULT (getdate()) FOR [Data]
GO

-- %% [markdown]
-- # [DF__Resgates__Data__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[Resgates] ADD  DEFAULT (getdate()) FOR [Data]
GO

-- %% [markdown]
-- # [DF__TiposMate__Multi__693CA210]

-- %%
ALTER TABLE [dbo].[TiposMaterial] ADD  DEFAULT ((1)) FOR [Multiplicador]
GO

-- %% [markdown]
-- # [DF__Usuarios__Pontos__4D94879B]

-- %%
ALTER TABLE [dbo].[Usuarios] ADD  DEFAULT ((0)) FOR [Pontos]
GO

-- %% [markdown]
-- # [DF__Usuarios__DataCa__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Usuarios] ADD  DEFAULT (getdate()) FOR [DataCadastro]
GO

-- %% [markdown]
-- # [FK__Locais__TipoMate__5165187F]

-- %%
ALTER TABLE [dbo].[Ecopontos]  WITH CHECK ADD FOREIGN KEY([TipoMaterialId])
REFERENCES [dbo].[TiposMaterial] ([Id])
GO

-- %% [markdown]
-- # [FK__Reciclage__Local__5629CD9C]

-- %%
ALTER TABLE [dbo].[Reciclagens]  WITH CHECK ADD FOREIGN KEY([LocalId])
REFERENCES [dbo].[Ecopontos] ([Id])
GO

-- %% [markdown]
-- # [FK__Reciclage__TipoM__571DF1D5]

-- %%
ALTER TABLE [dbo].[Reciclagens]  WITH CHECK ADD FOREIGN KEY([TipoMaterialId])
REFERENCES [dbo].[TiposMaterial] ([Id])
GO

-- %% [markdown]
-- # [FK__Reciclage__Usuar__5535A963]

-- %%
ALTER TABLE [dbo].[Reciclagens]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO

-- %% [markdown]
-- # [FK__Resgates__Recomp__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Resgates]  WITH CHECK ADD FOREIGN KEY([RecompensaId])
REFERENCES [dbo].[Recompensas] ([Id])
GO

-- %% [markdown]
-- # [FK__Resgates__Usuari__5CD6CB2B]

-- %%
ALTER TABLE [dbo].[Resgates]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO
